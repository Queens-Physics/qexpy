# %% [markdown]
# # Plotting with QExPy
# The first step is to import the module, we import it as p.
# We will also import the error module so that we can plot Measurement objects

# %%
import qexpy as q
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="02651985-523b-4bcb-aa5b-6e0b6f4bc419">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# The most common scenario in undergraduate laboratories is that we have measured some "depedent" quantity, $y$, as we varied some "independent" quantity $x$. Let us suppose that we have such a set of measurements, where the $x$ values had negligible (zero) uncertainty, and the y values each have the same uncertainty.
#
# We can represent the data using the MeasurementArray object:

# %%
x = q.MeasurementArray([1,2,3,4,5,6,7], error=[0], name="length", units="m")
y = q.MeasurementArray([2.1,3.9,6.3,8.1,9.6,11.3,14.6], error=[0.5], name="force", units="N")

# %% [markdown]
# We can now make a plot of $y$ versus $x$ and "show" it:

# %%
figure = q.MakePlot(x,y)
figure.show()
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="8c493a9f-d4a6-4132-98ea-9fe299d645bd"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("8c493a9f-d4a6-4132-98ea-9fe299d645bd").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }if ((window.Jupyter !== undefined) && Jupyter.notebook.kernel) {
#       comm_manager = Jupyter.notebook.kernel.comm_manager
#       comm_manager.register_target("a67c93bc-cd17-4b6d-a656-6c2b1101c7d5", function () {});
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("8c493a9f-d4a6-4132-98ea-9fe299d645bd");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '8c493a9f-d4a6-4132-98ea-9fe299d645bd' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"37bd2e35-9a63-451c-b420-8ac1fcde0317":{"roots":{"references":[{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"f1234791-6aed-4e60-bd9e-a42a146070af","type":"Line"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"height":{"units":"screen","value":0.2},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"width":{"units":"screen","value":5},"x":{"field":"x"},"y":{"field":"y"}},"id":"b6d6e596-a655-4102-91e0-dee5285e572a","type":"Rect"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"9b7aab20-ea82-402f-ae4b-a11831f7a706","type":"Line"},{"attributes":{"data_source":{"id":"e6f1fb4e-82d9-4095-8101-918ffa9e8f3b","type":"ColumnDataSource"},"glyph":{"id":"c437f058-a510-4af5-9f1b-789708f205aa","type":"Rect"},"hover_glyph":null,"nonselection_glyph":{"id":"b6d6e596-a655-4102-91e0-dee5285e572a","type":"Rect"},"selection_glyph":null},"id":"d10c0353-b3f3-451a-b9bc-d7d29597cfec","type":"GlyphRenderer"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"147ad05d-59f2-4b3c-b9bd-ed4fc602d4ed","type":"BoxAnnotation"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"height":{"units":"screen","value":0.2},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"width":{"units":"screen","value":5},"x":{"field":"x"},"y":{"field":"y"}},"id":"76839ad5-a2ac-476b-b5af-4ace49bacd6d","type":"Rect"},{"attributes":{"axis_label":"length [m]","formatter":{"id":"7d3c2476-7437-4bc6-b059-5f31495b06cf","type":"BasicTickFormatter"},"plot":{"id":"e75c7a79-69d5-4467-8647-1944a875a69f","subtype":"Figure","type":"Plot"},"ticker":{"id":"6da3fb10-2c3d-47e5-8891-b2a576e70f9a","type":"BasicTicker"}},"id":"325af36f-9843-4c3a-9e08-fcff2c27b1f9","type":"LinearAxis"},{"attributes":{"plot":{"id":"e75c7a79-69d5-4467-8647-1944a875a69f","subtype":"Figure","type":"Plot"}},"id":"757bc48f-32da-499c-811b-101d2db44fc5","type":"WheelZoomTool"},{"attributes":{"below":[{"id":"325af36f-9843-4c3a-9e08-fcff2c27b1f9","type":"LinearAxis"}],"left":[{"id":"753becb7-0148-40e7-aac6-a85366b1b616","type":"LinearAxis"}],"plot_height":400,"renderers":[{"id":"325af36f-9843-4c3a-9e08-fcff2c27b1f9","type":"LinearAxis"},{"id":"396d8d25-ee51-440b-adbc-18aa2c151efb","type":"Grid"},{"id":"753becb7-0148-40e7-aac6-a85366b1b616","type":"LinearAxis"},{"id":"a03513d3-5af5-4075-8972-2a1e08048fbf","type":"Grid"},{"id":"147ad05d-59f2-4b3c-b9bd-ed4fc602d4ed","type":"BoxAnnotation"},{"id":"60549218-6d0d-416f-b5ff-71cdbbf71c56","type":"Legend"},{"id":"cb830734-8979-4e29-b5b0-c5586b971d88","type":"GlyphRenderer"},{"id":"f2fee8af-5527-43c2-84c9-a152c46fb0d6","type":"GlyphRenderer"},{"id":"d10c0353-b3f3-451a-b9bc-d7d29597cfec","type":"GlyphRenderer"},{"id":"ab9a9492-15d8-46a7-b710-aea65fc64882","type":"GlyphRenderer"},{"id":"1cb60605-50bc-491a-920f-0068802387b7","type":"GlyphRenderer"},{"id":"55727f74-bcbc-406c-ac94-f7e8e26dba88","type":"GlyphRenderer"},{"id":"650afa5d-767b-4167-bbcb-1ed512f79769","type":"GlyphRenderer"},{"id":"f9a8994c-7561-49a3-9892-a5f1d668ea3b","type":"GlyphRenderer"},{"id":"17f2ef9e-534e-48f3-99ba-19a9425314f4","type":"GlyphRenderer"},{"id":"901aa091-1fe6-4756-9011-27b8ca6f1808","type":"GlyphRenderer"},{"id":"df2ff5a3-a735-4b35-840e-db1efb2f5f4a","type":"GlyphRenderer"},{"id":"8aaf391a-46f1-4d5a-9aba-96ac4070187b","type":"GlyphRenderer"},{"id":"826efd2e-1de3-4c3a-acfc-524b60ee8898","type":"GlyphRenderer"},{"id":"23e74899-9700-4596-ba91-e0b259a3de14","type":"GlyphRenderer"},{"id":"fc5006f1-1420-43bd-9a5f-088059150e7d","type":"GlyphRenderer"}],"title":{"id":"f6ce8cc2-2ffd-4534-a734-30746a889d13","type":" ...

# %% [markdown]
# ## Fitting
# QExPy easily handles fitting of data. A few common functions are automatically implemented (linear, polynomial, gaussian), but the used can also specify their own function. The fitting algorithm calls the scipy.optimize package in the background to perform the fit, and the fitted parameters are returned as Measurement objects (with uncertainties and correlations).
#
# A fit to a straight line of the above plot is easily done, and the residuals can also be shown. By default, the fit will show a  band around the fitted function computed using 1 standard error in the fitted parameters (and their correlation)

# %%
figure.fit("linear")
figure.add_residuals()
figure.show()
# Out:
# -----------------Fit results-------------------
# Fit of  dataset0  to  linear
# Fit parameters:
# dataset0_linear_fit0_fitpars_intercept = 0.0 +/- 0.4,
# dataset0_linear_fit0_fitpars_slope = 1.99 +/- 0.09
#
# Correlation matrix:
# [[ 1.    -0.894]
#  [-0.894  1.   ]]
#
# chi2/ndof = 4.49/4
# ---------------End fit results----------------
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="7d6626d0-1b95-4246-bced-0ca29eff07d6"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("7d6626d0-1b95-4246-bced-0ca29eff07d6").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }if ((window.Jupyter !== undefined) && Jupyter.notebook.kernel) {
#       comm_manager = Jupyter.notebook.kernel.comm_manager
#       comm_manager.register_target("544eba0d-9933-4e64-ab6d-8428b6dbc755", function () {});
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("7d6626d0-1b95-4246-bced-0ca29eff07d6");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '7d6626d0-1b95-4246-bced-0ca29eff07d6' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"c5d1d111-7c98-4946-ad6f-2e9f6da1f5f1":{"roots":{"references":[{"attributes":{"line_color":{"value":"#e41a1c"},"x":{"field":"x"},"y":{"field":"y"}},"id":"a1ec4a51-f0f7-4d7c-be2c-55b50db27e3b","type":"Line"},{"attributes":{"plot":{"id":"b7f0aaf3-45e1-4ce6-a0d9-55221c3b1ecd","subtype":"Figure","type":"Plot"},"ticker":{"id":"2a57d81a-1b99-4302-832b-542a99bbfe04","type":"BasicTicker"}},"id":"c39f6900-7707-41dc-ad7c-1de776aebb98","type":"Grid"},{"attributes":{"line_color":{"value":"#e41a1c"},"x":{"field":"x"},"y":{"field":"y"}},"id":"1afa318c-9b65-432c-aa35-e2cbaa54d0e4","type":"Line"},{"attributes":{"dimension":1,"plot":{"id":"48da1c68-4832-41bb-af1b-42a276fe26a7","subtype":"Figure","type":"Plot"},"ticker":{"id":"b23cc420-77e0-4b67-884a-a12b90cda039","type":"BasicTicker"}},"id":"7859fb88-2898-4497-9bc7-d0400e307d26","type":"Grid"},{"attributes":{"data_source":{"id":"9d8d9a3f-74bd-46f8-9502-384d42c1b9d8","type":"ColumnDataSource"},"glyph":{"id":"6443d0ed-1d9d-44fa-ae44-1c9b27850c4b","type":"Line"},"hover_glyph":null,"nonselection_glyph":{"id":"11f8ca2c-cdf2-496e-94c2-a8a509f2c944","type":"Line"},"selection_glyph":null},"id":"2ba78823-6179-45e5-ad51-a38f36829ca6","type":"GlyphRenderer"},{"attributes":{"plot":{"id":"b7f0aaf3-45e1-4ce6-a0d9-55221c3b1ecd","subtype":"Figure","type":"Plot"}},"id":"b49b232b-01e6-4488-8061-650cc15cd350","type":"SaveTool"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[4.0,4.0],"y":[-0.3857142857208,0.6142857142792]}},"id":"a54138e2-480a-4b52-ae9f-6f25f96505c5","type":"ColumnDataSource"},{"attributes":{"fill_color":{"value":"#e41a1c"},"height":{"units":"screen","value":0.2},"line_color":{"value":"#e41a1c"},"width":{"units":"screen","value":5},"x":{"field":"x"},"y":{"field":"y"}},"id":"0011ae35-2957-4634-aa5c-0f37bb15b08d","type":"Rect"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"AAAAAAAA8D8AAAAAAAAAQAAAAAAAAAhAAAAAAAAAEEAAAAAAAAAUQAAAAAAAABhAAAAAAAAAHEA=","dtype":"float64","shape":[7]},"y":{"__ndarray__":"zczMzMzMAEAzMzMzMzMPQDMzMzMzMxlAMzMzMzMzIEAzMzMzMzMjQJqZmZmZmSZAMzMzMzMzLUA=","dtype":"float64","shape":[7]}}},"id":"bfb14f37-c444-4743-974e-329031040046","type":"ColumnDataSource"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"d4ca3ec4-a3ee-49c3-a5a6-459aa2b192b4","type":"Line"},{"attributes":{"fill_color":{"value":"#e41a1c"},"height":{"units":"screen","value":0.2},"line_color":{"value":"#e41a1c"},"width":{"units":"screen","value":5},"x":{"field":"x"},"y":{"field":"y"}},"id":"82e00f6b-ffd5-4198-9a9d-86435ca90ae4","type":"Rect"},{"attributes":{"callback":null,"end":17.746875,"start":0.925},"id":"72aec5b0-16fb-41d1-b6c8-f6c5d6f33309","type":"Range1d"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"height":{"units":"screen","value":0.2},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"width":{"units":"screen","value":5},"x":{"field":"x"},"y":{"field":"y"}},"id":"b778bc79-3cb2-4ecc-bb37-0c92fa4e8068","type":"Rect"},{"attributes":{"line_color":{"value":"#e41a1c"},"x":{"field":"x"},"y":{"field":"y"}},"id":"0a9a405a-2659-470f-b3bb-2aebfa8318da","type":"Line"},{"attributes":{"line_color":{"value":"#e41a1c"},"x":{"field":"x"},"y":{"field":"y"}},"id":"73319625-3587-400c-a43e-2067fb42f7a3","type":"Line"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[4.0,4.0],"y":[7.6,8.6]}},"id":"f656b14b-504a-4bf3-9a63-aaf924aaf571","type":"ColumnDataSource"},{"attributes":{"fill_color":{"value":"#e41a1c"},"height":{"units":"screen","value":0.2},"line_color":{"value":"#e41a1c"},"width":{"units":"screen","value":5},"x":{"field":"x"},"y":{"field":"y"}},"id":"79f2abe3-7993-4534-b443-d569f04c60ff","type":"Rect"},{"attributes":{"data_source":{"id":"bab04d2d-e1c2-48a9-8075-1e525bc996dd","type":"ColumnDataSource"},"glyph":{"id":"7016df0f-24c5-488f-b452-f3b8e7b5932d","type":"Rect"},"hover_glyph":null,"nonselection_g ...

# %% [markdown]
# If the user wishes to specify a custom function to fit, then the function can be specified as a python function. The first argument to the function must be the dependent variable, and the second argument must be an array (or tuple) corresponding to the parameters to be fit.
#
# In order to properly fit the user-supplied function, QExPy needs to have a guess for the values of the parameters.

# %%
#Define a simple quadratic
def myModel(x, *parameters):
    return parameters[0]+parameters[1]*x+parameters[2]*x**2

#Carry out the fit, and change the color of the fit function
figure.fit(model=myModel, parguess=[1,1,2], fitcolor="blue")
figure.show()
# Out:
# -----------------Fit results-------------------
# Fit of  dataset0  to  custom
# Fit parameters:
# dataset0_custom_fit1_fitpars_par0 = 0.5 +/- 0.8,
# dataset0_custom_fit1_fitpars_par1 = 1.7 +/- 0.4,
# dataset0_custom_fit1_fitpars_par2 = 0.04 +/- 0.05
#
# Correlation matrix:
# [[ 1.    -0.924  0.84 ]
#  [-0.924  1.    -0.977]
#  [ 0.84  -0.977  1.   ]]
#
# chi2/ndof = 3.94/3
# ---------------End fit results----------------
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="8df6f628-5824-4b5f-a58b-1867ffb908a4"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById
type":"Line"},"hover_glyph":null,"nonselection_glyph":{"id":"0ec1d5a7-19ec-4daf-8a53-414afd17c1de","type":"Line"},"selection_glyph":null},"i ...

# %% [markdown]
# ## Showing multiple data sets on one figure
# QExPy can also show multiple data sets on the same plot, and each data set can have its own individual fit.
#
# Suppose that we have a second set of measurement of the y values for the same x values as above. The easiest way to plot them along with the initial values, is to create a DataSet and to add that Dataset to the figure:

# %%
y2 = q.MeasurementArray([2.4,4.2,5.9,8.2,9.2,12.0,13.6], error=[0.5], name="force", units="N")
dataset = q.XYDataSet(x,y2)
figure.add_dataset(dataset)
figure.show()
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="842076f7-9986-4a37-913b-d13e6ba73597"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("842076f7-9986-4a37-913b-d13e6ba73597").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }if ((window.Jupyter !== undefined) && Jupyter.notebook.kernel) {
#       comm_manager = Jupyter.notebook.kernel.comm_manager
#       comm_manager.register_target("ab3e4d72-af27-4436-8417-e50c3bcb0b79", function () {});
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("842076f7-9986-4a37-913b-d13e6ba73597");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '842076f7-9986-4a37-913b-d13e6ba73597' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"e63c6cfc-cea9-466e-a439-f422e019e193":{"roots":{"references":[{"attributes":{"fill_color":{"value":"#e41a1c"},"height":{"units":"screen","value":0.2},"line_color":{"value":"#e41a1c"},"width":{"units":"screen","value":5},"x":{"field":"x"},"y":{"field":"y"}},"id":"47c5da2b-c7b3-40b6-a68f-b97eb514f6d1","type":"Rect"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"height":{"units":"screen","value":0.2},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"width":{"units":"screen","value":5},"x":{"field":"x"},"y":{"field":"y"}},"id":"4e6f99eb-a093-4345-ac5b-d5f9978899ed","type":"Rect"},{"attributes":{"data_source":{"id":"45c97a64-190f-4a71-a228-0d9905263359","type":"ColumnDataSource"},"glyph":{"id":"bc065157-f0c9-45ba-b735-ffb7b953e7d9","type":"Rect"},"hover_glyph":null,"nonselection_glyph":{"id":"59dc4cc0-9f96-4906-9540-6f0d4ade56d5","type":"Rect"},"selection_glyph":null},"id":"3fd33faa-e224-4b42-9cb8-db942e98c419","type":"GlyphRenderer"},{"attributes":{"label":{"value":"dataset0_custom"},"renderers":[{"id":"3fa9a6cc-e636-4924-80d4-6ee557801e6c","type":"GlyphRenderer"},{"id":"0183325f-ad2d-4f27-afe1-185257d6604a","type":"GlyphRenderer"}]},"id":"b7139945-00bf-40ee-add9-19d273c2ad30","type":"LegendItem"},{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":[4.0,4.0],"y":[7.6,8.6]}},"id":"8ddb8d02-29e9-49ae-aaad-760c392eadee","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[7.0,7.0],"y":[-0.045238095037692716,0.9547619049623073]}},"id":"78d3417c-b18a-4b06-a3dc-89a7fc1471d8","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"57b98afd-ee62-40c0-ae20-c1d694465e1d","type":"ColumnDataSource"},"glyph":{"id":"9b9a4040-12e7-4d04-bef3-bba77419337d","type":"Line"},"hover_glyph":null,"nonselection_glyph":{"id":"c286d2be-db64-4620-bc5c-d8050ef97417","type":"Line"},"selection_glyph":null},"id":"9faa0b1c-a414-48b1-96d9-3daa657453a1","type":"GlyphRenderer"},{"attributes":{"line_color":{"value":"#377eb8"},"x":{"field":"x"},"y":{"field":"y"}},"id":"e44094b5-b5c4-46a3-80ce-2fae6c508d75","type":"Line"},{"attributes":{"line_color":{"value":"#e41a1c"},"x":{"field":"x"},"y":{"field":"y"}},"id":"b82d2007-769a-4ffc-adb9-a1d8a51f9389","type":"Line"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[3.0,3.0],"y":[-0.07857142853624932,0.9214285714637507]}},"id":"9ecdd550-302d-4b9f-8a66-ff0fdf9be26f","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":[2.0,2.0],"y":[3.7,4.7]}},"id":"143dca5c-969b-4211-bcde-338e98ff1a92","type":"ColumnDataSource"},{"attributes":{"plot":{"id":"3ee707f4-48af-4303-81ce-099e0e148fd2","subtype":"Figure","type":"Plot"}},"id":"99b26281-ea0c-4b96-b794-35220680c435","type":"WheelZoomTool"},{"attributes":{"fill_color":{"value":"#377eb8"},"height":{"units":"screen","value":0.2},"line_color":{"value":"#377eb8"},"width":{"units":"screen","value":5},"x":{"field":"x"},"y":{"field":"y"}},"id":"39fae384-8f90-4c4b-a1ff-4c5da2d362f7","type":"Rect"},{"attributes":{"fill_color":{"value":"#e41a1c"},"height":{"units":"screen","value":0.2},"line_color":{"value":"#e41a1c"},"width":{"units":"screen","value":5},"x":{"field":"x"},"y":{"field":"y"}},"id":"4f6e3c0e-0531-415c-b5aa-998fae0dcdeb","type":"Rect"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"ee3ebf4e-a32e-4816-8d65-240d289be5d8","type":"BoxAnnotation"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"height":{"units":"screen","value":0.2},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"width":{"units":"screen","value":5},"x":{"field":"x"},"y":{"field":"y"}},"id":"7da15575-1c90-4a5e-8d4 ...
