# %% [markdown]
# # Plotting with QExPy
# The first step is to import the module, we import it as p.
# We will also import the error module so that we can plot Measurement objects

# %%
import qexpy as q
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="0ee72846-1e96-4962-a4d5-76df45cfd883">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# The most common scenario in undergraduate laboratories is that we have measured some "depedent" quantity, $y$, as we varied some "independent" quantity $x$. Let us suppose that we have such a set of measurements, where the $x$ values had negligible (zero) uncertainty, and the y values each have the same uncertainty.
#
# We can represent the data using the MeasurementArray object:

# %%
x = q.MeasurementArray([1,2,3,4,5,6,7], error=[0], name="length", units="m")
y = q.MeasurementArray([2.1,3.9,6.3,8.1,9.6,11.3,14.6], error=[0.5], name="force", units="N")

# %% [markdown]
# We can now make a plot of $y$ versus $x$ and "show" it:

# %%
figure = q.MakePlot(x,y)
figure.show()
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="28b632ab-2bb5-466b-b664-059ba12f8064"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("28b632ab-2bb5-466b-b664-059ba12f8064").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }if ((window.Jupyter !== undefined) && Jupyter.notebook.kernel) {
#       comm_manager = Jupyter.notebook.kernel.comm_manager
#       comm_manager.register_target("ed1ef0fc-ae36-462e-8316-e12078b24a58", function () {});
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("28b632ab-2bb5-466b-b664-059ba12f8064");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '28b632ab-2bb5-466b-b664-059ba12f8064' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"09b7f096-2b53-4cdd-bdc2-07bb23d283d6":{"roots":{"references":[{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":[3.0,3.0],"y":[5.8,6.8]}},"id":"2ab7f0b6-809d-4928-8929-748a335dd281","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":[6.0,6.0],"y":[10.8,11.8]}},"id":"3de9127a-96eb-4658-a9e1-d3234ab0e123","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[1.0,1.0],"y":[1.6,2.6]}},"id":"c9e65c6c-7ca9-454b-a11b-c7035c1d2539","type":"ColumnDataSource"},{"attributes":{"line_color":{"value":"#e41a1c"},"x":{"field":"x"},"y":{"field":"y"}},"id":"d80fc554-ce31-4ef5-9523-736d46f34b82","type":"Line"},{"attributes":{"data_source":{"id":"90114950-a154-4328-a071-8c20b933e6af","type":"ColumnDataSource"},"glyph":{"id":"0c226503-8c8b-40fa-8fc8-8dc8bb6412ad","type":"Line"},"hover_glyph":null,"nonselection_glyph":{"id":"27d6e93e-3e09-45c7-a164-404f35c9fef3","type":"Line"},"selection_glyph":null},"id":"3f5b656c-6149-4a2b-bc8a-73303206b647","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":[5.0,5.0],"y":[9.1,10.1]}},"id":"7a0fdca2-7688-41b0-8b1a-cb687994116c","type":"ColumnDataSource"},{"attributes":{"plot":{"id":"1caffb4a-99a5-4898-9ed0-d87070998273","subtype":"Figure","type":"Plot"}},"id":"1f70255c-59fe-4605-8d14-06ec494b8161","type":"PanTool"},{"attributes":{"data_source":{"id":"1b60d90d-24ee-4a36-bb89-bbacb66929a1","type":"ColumnDataSource"},"glyph":{"id":"5704d62d-ce95-4d4b-b2cd-c18f2ce400da","type":"Line"},"hover_glyph":null,"nonselection_glyph":{"id":"baf729c4-19e6-40e9-a905-511a46f314c6","type":"Line"},"selection_glyph":null},"id":"ab16e57b-9794-4d95-a56a-5b34a6a7eb97","type":"GlyphRenderer"},{"attributes":{"line_color":{"value":"#e41a1c"},"x":{"field":"x"},"y":{"field":"y"}},"id":"3db276bc-b209-4524-af0c-06e2037ab61d","type":"Line"},{"attributes":{"data_source":{"id":"7efd50fe-9198-4ec3-a9c8-836f97c3c449","type":"ColumnDataSource"},"glyph":{"id":"3db276bc-b209-4524-af0c-06e2037ab61d","type":"Line"},"hover_glyph":null,"nonselection_glyph":{"id":"ea11070a-ace9-4f87-bea6-8dd44449959e","type":"Line"},"selection_glyph":null},"id":"1b22ab94-66e4-4444-9b0f-0fb08c4dafd8","type":"GlyphRenderer"},{"attributes":{},"id":"2347c2d9-51be-4dfa-ad8a-93bc3702ba6a","type":"BasicTicker"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"height":{"units":"screen","value":0.2},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"width":{"units":"screen","value":5},"x":{"field":"x"},"y":{"field":"y"}},"id":"03ae662e-fc21-4f2c-9a1a-c3f77171350d","type":"Rect"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"e90ac6dd-6623-4621-8800-da59130ba801","type":"SaveTool"},{"id":"1f70255c-59fe-4605-8d14-06ec494b8161","type":"PanTool"},{"id":"7becd513-313c-4033-9861-1c242397d292","type":"BoxZoomTool"},{"id":"787827a8-1cf0-48cd-91b0-25b9b9d4ba3e","type":"WheelZoomTool"},{"id":"94e0a2ba-7cf0-4776-9ad4-e675191e4bec","type":"ResetTool"}]},"id":"cf56ac8c-04e3-4517-add5-8d0861428fb9","type":"Toolbar"},{"attributes":{"axis_label":"force []","formatter":{"id":"498adccd-6484-489c-ba24-179ce73b6e94","type":"BasicTickFormatter"},"plot":{"id":"1caffb4a-99a5-4898-9ed0-d87070998273","subtype":"Figure","type":"Plot"},"ticker":{"id":"2347c2d9-51be-4dfa-ad8a-93bc3702ba6a","type":"BasicTicker"}},"id":"6c123f71-0b15-4f08-864a-4723af17e1e6","type":"LinearAxis"},{"attributes":{"data_source":{"id":"9fcad81c-9998-4405-a746-3236614fa577","type":"ColumnDataSource"},"glyph":{"id":"5bce8b24-003a-4f61-8e6d-8eba423ab938","type":"Circle"},"hover_glyph":null,"nonselection_glyph":{"id":"fec93e6a-a825-4d9b-a272-e06a695c7f3e","type":"Circle"},"selection_glyph":null},"id":"8476d52e-f968-4618-b2f7-140fac01c041","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"7a0fdca2-7688-41b0-8b1a-cb687994116c","type":"ColumnDataSource"},"glyph":{"id":"fdabd ...

# %% [markdown]
# ## Fitting
# QExPy easily handles fitting of data. A few common functions are automatically implemented (linear, polynomial, gaussian), but the used can also specify their own function. The fitting algorithm calls the scipy.optimize package in the background to perform the fit, and the fitted parameters are returned as Measurement objects (with uncertainties and correlations).
#
# A fit to a straight line of the above plot is easily done, and the residuals can also be shown. By default, the fit will show a  band around the fitted function computed using 1 standard error in the fitted parameters (and their correlation)

# %%
figure.fit("linear")
figure.add_residuals()
figure.show()
# Out:
# -----------------Fit results-------------------
# Fit of  dataset0  to  linear
# Fit parameters:
# dataset0_linear_fit0_fitpars_intercept = 0.0 +/- 0.4,
# dataset0_linear_fit0_fitpars_slope = 1.99 +/- 0.09
#
# Correlation matrix:
# [[ 1.    -0.894]
#  [-0.894  1.   ]]
#
# chi2/ndof = 4.49/4
# ---------------End fit results----------------
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="782c5e64-9506-4aa8-9a24-7c13ed1a02d0"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("782c5e64-9506-4aa8-9a24-7c13ed1a02d0").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }if ((window.Jupyter !== undefined) && Jupyter.notebook.kernel) {
#       comm_manager = Jupyter.notebook.kernel.comm_manager
#       comm_manager.register_target("fe54207d-5050-4b09-b8b3-70aed066fbbc", function () {});
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("782c5e64-9506-4aa8-9a24-7c13ed1a02d0");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '782c5e64-9506-4aa8-9a24-7c13ed1a02d0' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"43d2a731-87a2-441c-a0f0-47911cc014a3":{"roots":{"references":[{"attributes":{"fill_color":{"value":"#e41a1c"},"height":{"units":"screen","value":0.2},"line_color":{"value":"#e41a1c"},"width":{"units":"screen","value":5},"x":{"field":"x"},"y":{"field":"y"}},"id":"59ff9ff6-668a-4862-826f-3d0651408420","type":"Rect"},{"attributes":{"fill_color":{"value":"#e41a1c"},"height":{"units":"screen","value":0.2},"line_color":{"value":"#e41a1c"},"width":{"units":"screen","value":5},"x":{"field":"x"},"y":{"field":"y"}},"id":"8472210f-dfde-4193-8ce4-ed0866294962","type":"Rect"},{"attributes":{"dimension":1,"plot":{"id":"47eabeb9-5c17-4068-921e-17b3b1da9691","subtype":"Figure","type":"Plot"},"ticker":{"id":"bd04a27e-b094-4a08-864d-205d7899f099","type":"BasicTicker"}},"id":"ea21f7c0-b596-40b5-81c6-8a6d7cd1a3fe","type":"Grid"},{"attributes":{"data_source":{"id":"40aef14b-64e0-43d5-9bc9-d3b23652dde2","type":"ColumnDataSource"},"glyph":{"id":"5ab0f165-5a9f-44bf-aa0c-b20427418521","type":"Rect"},"hover_glyph":null,"nonselection_glyph":{"id":"ad52faa8-1964-4a78-894f-e16ee63193c7","type":"Rect"},"selection_glyph":null},"id":"1697de1d-0322-42b3-a50e-aa61244f8237","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"height":{"units":"screen","value":0.2},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"width":{"units":"screen","value":5},"x":{"field":"x"},"y":{"field":"y"}},"id":"06a9cab4-c689-4732-85c7-062006b81dd4","type":"Rect"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"AAAAAAAA8D8AAAAAAAAAQAAAAAAAAAhAAAAAAAAAEEAAAAAAAAAUQAAAAAAAABhAAAAAAAAAHEA=","dtype":"float64","shape":[7]},"y":{"__ndarray__":"gBJJkiRJsj9gQ0Qd1EG9vxAAMjMzM9M/gKo6HdRBvT8A3sdXfMXXv/DMCHVQB+W/UIgFdVAH5T8=","dtype":"float64","shape":[7]}}},"id":"beef5798-c537-4245-b74a-ead00cd220af","type":"ColumnDataSource"},{"attributes":{"axis_label":"length []","formatter":{"id":"e96bf230-6f37-496c-9679-a62847f2abbc","type":"BasicTickFormatter"},"plot":{"id":"4b9bc094-2360-4f62-902d-75be19dea3e6","subtype":"Figure","type":"Plot"},"ticker":{"id":"b2ed0480-c325-443b-95f3-60c52c22e015","type":"BasicTicker"}},"id":"b58d867b-0157-4660-ac41-54f370240a18","type":"LinearAxis"},{"attributes":{"line_color":{"value":"#e41a1c"},"x":{"field":"x"},"y":{"field":"y"}},"id":"e4f5e83a-9b91-4e88-9d64-87b5eb382697","type":"Line"},{"attributes":{"data_source":{"id":"1e858215-0ae5-4d09-b0c7-4047a0fd88a5","type":"ColumnDataSource"},"glyph":{"id":"f435007b-018c-48b6-8348-da93243b9fee","type":"Line"},"hover_glyph":null,"nonselection_glyph":{"id":"11818b39-3c8c-4426-a769-196afd17ea7c","type":"Line"},"selection_glyph":null},"id":"b66e9f51-602f-4ed5-a5cc-bbf5e582c13c","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"e0795ee1-c55d-492a-8d93-50fc45828d07","type":"Circle"},{"attributes":{"plot":null,"text":""},"id":"d9d3733c-3bc0-4f56-8395-d91fc3a31386","type":"Title"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"e7089af6-51ab-4aea-b7db-60f12ebe4839","type":"Line"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"09244d68-1841-411e-b0aa-d8319fef82d2","type":"BoxAnnotation"},{"attributes":{"fill_color":{"value":"#e41a1c"},"line_color":{"value":"#e41a1c"},"x":{"field":"x"},"y":{"field":"y"}},"id":"d233d930-701b-448d-9de8-9e1ccadfc6c5","type":"Circle"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"...","dtype":"float64","shape":[200]},"y":{"__ndarray__":"...","dtype":"fl ...

# %% [markdown]
# If the user wishes to specify a custom function to fit, then the function can be specified as a python function. The first argument to the function must be the dependent variable, and the second argument must be an array (or tuple) corresponding to the parameters to be fit.
#
# In order to properly fit the user-supplied function, QExPy needs to have a guess for the values of the parameters.

# %%
#Define a simple quadratic
def myModel(x, *parameters):
    return parameters[0]+parameters[1]*x+parameters[2]*x**2

#Carry out the fit, and change the color of the fit function
figure.fit(model=myModel, parguess=[1,1,2], fitcolor="blue")
figure.show()
# Out:
# -----------------Fit results-------------------
# Fit of  dataset0  to  custom
# Fit parameters:
# dataset0_custom_fit1_fitpars_par0 = 0.5 +/- 0.8,
# dataset0_custom_fit1_fitpars_par1 = 1.7 +/- 0.4,
# dataset0_custom_fit1_fitpars_par2 = 0.04 +/- 0.05
#
# Correlation matrix:
# [[ 1.    -0.924  0.84 ]
#  [-0.924  1.    -0.977]
#  [ 0.84  -0.977  1.   ]]
#
# chi2/ndof = 3.94/3
# ---------------End fit results----------------
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="0f820c51-1d1a-41d3-9dd1-fc752cc9f1ca"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("0f820c51-1d1a-41d3-9dd1-fc752cc9f1ca").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }if ((window.Jupyter !== undefined) && Jupyter.notebook.kernel) {
#       comm_manager = Jupyter.notebook.kernel.comm_manager
#       comm_manager.register_target("621759c9-fdc9-4d46-804b-175a10ec80a4", function () {});
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("0f820c51-1d1a-41d3-9dd1-fc752cc9f1ca");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '0f820c51-1d1a-41d3-9dd1-fc752cc9f1ca' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"7c1c36d5-b02a-441e-90e4-5760ea6ddb14":{"roots":{"references":[{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":[4.0,4.0],"y":[7.6,8.6]}},"id":"1760ddcc-8568-45b6-baee-1b3b8f309c74","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"68f7fce7-55c3-4342-993d-08aa31951a36","type":"Patch"},{"attributes":{"data_source":{"id":"891e7e6c-f54d-4952-b48b-ac661bc3f210","type":"ColumnDataSource"},"glyph":{"id":"4d6dadab-a0cc-48a8-b5ef-3eadefeb86de","type":"Line"},"hover_glyph":null,"nonselection_glyph":{"id":"e059878a-f812-4985-ab19-f87e5251a50b","type":"Line"},"selection_glyph":null},"id":"feb9dbf8-b585-4e3e-ba09-62329116efaf","type":"GlyphRenderer"},{"attributes":{"fill_color":{"value":"#e41a1c"},"line_color":{"value":"#e41a1c"},"x":{"field":"x"},"y":{"field":"y"}},"id":"ebfebe87-0367-4db8-82fe-2e0da9861495","type":"Circle"},{"attributes":{"fill_color":{"value":"#e41a1c"},"height":{"units":"screen","value":0.2},"line_color":{"value":"#e41a1c"},"width":{"units":"screen","value":5},"x":{"field":"x"},"y":{"field":"y"}},"id":"ff8e3f38-9e68-41e1-9485-7dc52dd6419e","type":"Rect"},{"attributes":{"data_source":{"id":"4a88775d-0b9e-4860-b0f9-70af45aadf32","type":"ColumnDataSource"},"glyph":{"id":"ff8e3f38-9e68-41e1-9485-7dc52dd6419e","type":"Rect"},"hover_glyph":null,"nonselection_glyph":{"id":"0fd966bd-3668-4398-a9ed-a58af40406e9","type":"Rect"},"selection_glyph":null},"id":"8c0e39dc-2268-426a-a1ad-0f9dbe2abf62","type":"GlyphRenderer"},{"attributes":{"fill_color":{"value":"#e41a1c"},"height":{"units":"screen","value":0.2},"line_color":{"value":"#e41a1c"},"width":{"units":"screen","value":5},"x":{"field":"x"},"y":{"field":"y"}},"id":"9a37ba16-9869-454c-ba8f-e6cdfa5c1dbe","type":"Rect"},{"attributes":{"axis_label":"force []","formatter":{"id":"90052432-5062-4383-affe-b77e3c47949c","type":"BasicTickFormatter"},"plot":{"id":"154bb221-f0ae-478a-bf03-1079523758f4","subtype":"Figure","type":"Plot"},"ticker":{"id":"896be1cb-342e-47a1-96ed-2e96c2c44905","type":"BasicTicker"}},"id":"8a97d082-dc2d-4875-941f-9a21df5e4f36","type":"LinearAxis"},{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":[1.0,1.0],"y":[-0.6309523809484738,0.36904761905152617]}},"id":"4a88775d-0b9e-4860-b0f9-70af45aadf32","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"04db3ac7-1512-475c-8695-861b5c08492b","type":"ColumnDataSource"},"glyph":{"id":"0e16d05e-558b-4978-8cce-a1937b15f64b","type":"Line"},"hover_glyph":null,"nonselection_glyph":{"id":"01af1706-2439-4c01-bfa2-ae69ec477d85","type":"Line"},"selection_glyph":null},"id":"c04f0329-05f5-460f-b6d2-5e50d1220787","type":"GlyphRenderer"},{"attributes":{"children":[{"id":"154bb221-f0ae-478a-bf03-1079523758f4","subtype":"Figure","type":"Plot"}]},"id":"1768c82d-0247-459c-93cc-b2de798a7797","type":"Row"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"6d01da7d-f847-4d9a-93c0-147470c4193d","type":"SaveTool"},{"id":"bd995b7d-9823-4fd2-9ad1-3a3557e6ae68","type":"PanTool"},{"id":"a7a7beec-58d9-4983-9f7b-c2f8e7355665","type":"BoxZoomTool"},{"id":"c9d15b9a-09c0-4efe-b673-2969a81e1079","type":"WheelZoomTool"},{"id":"96ec5f28-e899-4c9a-8cb1-5a77c646c901","type":"ResetTool"}]},"id":"63b2e55d-761b-49b4-9b02-b5203b03d9c8","type":"Toolbar"},{"attributes":{"data_source":{"id":"917a1c00-3696-4434-a191-4db9df3f9127","type":"ColumnDataSource"},"glyph":{"id":"cb9d62f2-2cb9-404b-802f-dc71917d05e3","type":"Line"},"hover_glyph":null,"nonselection_glyph":{"id":"32c72487-db30-4be6-a4f6-8ecf9874ce54","type":"Line"},"selection_glyph":null},"id":"08e77d39-d17c-4193-9c25-f352d5938522","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":[6.0,6.0],"y":[-1.1571428569965931,-0.15714285699659314]}},"id":"a770319b-56b5-4944-b853-c205c8a83525","type":"Colum ...

# %% [markdown]
# ## Showing multiple data sets on one figure
# QExPy can also show multiple data sets on the same plot, and each data set can have its own individual fit.
#
# Suppose that we have a second set of measurement of the y values for the same x values as above. The easiest way to plot them along with the initial values, is to create a DataSet and to add that Dataset to the figure:

# %%
y2 = q.MeasurementArray([2.4,4.2,5.9,8.2,9.2,12.0,13.6], error=[0.5], name="force", units="N")
dataset = q.XYDataSet(x,y2)
figure.add_dataset(dataset)
figure.show()
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="2c5627b9-c9dd-4a83-b1d7-f27c9e1c0b3e"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("2c5627b9-c9dd-4a83-b1d7-f27c9e1c0b3e").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }if ((window.Jupyter !== undefined) && Jupyter.notebook.kernel) {
#       comm_manager = Jupyter.notebook.kernel.comm_manager
#       comm_manager.register_target("57b5ee26-da34-4482-8e12-57ab3bb8d5ac", function () {});
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("2c5627b9-c9dd-4a83-b1d7-f27c9e1c0b3e");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '2c5627b9-c9dd-4a83-b1d7-f27c9e1c0b3e' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"32fb5335-1c71-4ac0-b43e-12a2c4cac582":{"roots":{"references":[{"attributes":{"data_source":{"id":"28adf5c9-159a-44b0-992f-c4a18f3cfbd1","type":"ColumnDataSource"},"glyph":{"id":"aaf7a408-f165-4b93-8ba8-d914c6eb40f1","type":"Rect"},"hover_glyph":null,"nonselection_glyph":{"id":"b81ac474-5ad8-49b3-8526-3e60d4c14bdb","type":"Rect"},"selection_glyph":null},"id":"8608c5bd-2d2b-460e-8485-591680831a19","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"8799f04f-7ba7-4cd7-a918-1a339c918c49","type":"ColumnDataSource"},"glyph":{"id":"23e9f500-5998-4109-a6c4-d0152a093f01","type":"Rect"},"hover_glyph":null,"nonselection_glyph":{"id":"80b2ecfd-2890-4a7f-aae6-ee3525b88d1f","type":"Rect"},"selection_glyph":null},"id":"fcef43ad-4c52-4331-938a-5750bf1bec0f","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":[6.0,6.0],"y":[10.8,11.8]}},"id":"a3e06ae4-74f0-4285-b01a-d3710bee5e26","type":"ColumnDataSource"},{"attributes":{"overlay":{"id":"07a50ac6-18c1-479f-9ee6-68e89112c3ea","type":"BoxAnnotation"},"plot":{"id":"bcb5bfe0-5502-485a-a848-d20a10f408b3","subtype":"Figure","type":"Plot"}},"id":"895d1aec-837c-4944-a9ad-d779633c5d20","type":"BoxZoomTool"},{"attributes":{"data_source":{"id":"6651b2b7-2d9f-4399-a1f5-4204c3a0f64a","type":"ColumnDataSource"},"glyph":{"id":"d4b259d9-a220-403d-be44-8b3f48d5789a","type":"Rect"},"hover_glyph":null,"nonselection_glyph":{"id":"67fc0c2f-59f5-4eb3-bd94-37844feef994","type":"Rect"},"selection_glyph":null},"id":"e7750798-4e32-4384-a236-63b6883a7581","type":"GlyphRenderer"},{"attributes":{"fill_color":{"value":"#377eb8"},"height":{"units":"screen","value":0.2},"line_color":{"value":"#377eb8"},"width":{"units":"screen","value":5},"x":{"field":"x"},"y":{"field":"y"}},"id":"d4b259d9-a220-403d-be44-8b3f48d5789a","type":"Rect"},{"attributes":{"fill_color":{"value":"#377eb8"},"height":{"units":"screen","value":0.2},"line_color":{"value":"#377eb8"},"width":{"units":"screen","value":5},"x":{"field":"x"},"y":{"field":"y"}},"id":"f3f0a118-3d78-4803-8d9a-97415dd0c1d4","type":"Rect"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"height":{"units":"screen","value":0.2},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"width":{"units":"screen","value":5},"x":{"field":"x"},"y":{"field":"y"}},"id":"4437c10f-cced-4001-9709-6c56bc947e2a","type":"Rect"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"height":{"units":"screen","value":0.2},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"width":{"units":"screen","value":5},"x":{"field":"x"},"y":{"field":"y"}},"id":"67fc0c2f-59f5-4eb3-bd94-37844feef994","type":"Rect"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[6.0,6.0],"y":[10.8,11.8]}},"id":"946b6b64-9cc2-4ee2-be1d-4dab58af43fc","type":"ColumnDataSource"},{"attributes":{"line_color":{"value":"#377eb8"},"x":{"field":"x"},"y":{"field":"y"}},"id":"762dfb9b-84ab-4218-81b7-5a3daace7dd7","type":"Line"},{"attributes":{},"id":"1cd2f48a-5f81-4694-816f-5fce2f48d476","type":"BasicTicker"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[3.0,3.0],"y":[-0.07857142853624932,0.9214285714637507]}},"id":"d28d26bf-5a6c-45cb-ade1-da11bc335929","type":"ColumnDataSource"},{"attributes":{"line_color":{"value":"#377eb8"},"x":{"field":"x"},"y":{"field":"y"}},"id":"401b3ad9-a9d4-47b4-90f8-710d4b0c050d","type":"Line"},{"attributes":{"line_color":{"value":"#e41a1c"},"x":{"field":"x"},"y":{"field":"y"}},"id":"98536524-80e3-4eb3-8e97-e898208b239d","type":"Line"},{"attributes":{"data_source":{"id":"8e81b609-890c-4e4e-aa07-3ee47384c9e8","type":"ColumnDataSource"},"glyph":{"id":"388b8d2a-ed79-4c20-b606-2749e94b8d0e","type":"Line"},"hover_glyph":null,"nonselection_glyph":{"id":"9170eb3e-0124-45e0-8e5f-66cdfece5ee3","type":"Line"},"selection_glyph":null},"id":"531d28fd-495d-4b0d-9b7b-65a4d8aaff1d","type":"GlyphRenderer"},{"attributes":{"line_alpha":{"value":0.1},"line ...
