# %% [markdown]
# # Plotting with QExPy
# The first step is to import the module, we import it as p.
# We will also import the error module so that we can plot Measurement objects

# %%
import qexpy as q
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="541eeb39-8720-4a5d-a2d0-33ebe73336a7">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# The most common scenario in undergraduate laboratories is that we have measured some "depedent" quantity, $y$, as we varied some "independent" quantity $x$. Let us suppose that we have such a set of measurements, where the $x$ values had negligible (zero) uncertainty, and the y values each have the same uncertainty.
#
# We can represent the data using the MeasurementArray object:

# %%
x = q.MeasurementArray([1,2,3,4,5,6,7], error=[0], name="length", units="m")
y = q.MeasurementArray([2.1,3.9,6.3,8.1,9.6,11.3,14.6], error=[0.5], name="force", units="N")

# %% [markdown]
# We can now make a plot of $y$ versus $x$ and "show" it:

# %%
figure = q.MakePlot(x,y)
figure.show()
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="f5434813-c1cc-4c95-9511-c6395d993d98"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("f5434813-c1cc-4c95-9511-c6395d993d98");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'f5434813-c1cc-4c95-9511-c6395d993d98' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"d5ff0a6f-6d25-4d71-80fa-6be20bb69ad6":{"roots":{"references":[{"attributes":{"plot":{"id":"71050f54-5b8d-445a-95f7-84babe487724","subtype":"Figure","type":"Plot"},"ticker":{"id":"78a3cf00-761e-48e9-8eac-9397ac09e711","type":"BasicTicker"}},"id":"cc42ad4d-5080-485a-98ad-e1d0c4d0fe65","type":"Grid"},{"attributes":{"axis_label":"length [m]","formatter":{"id":"051a1724-a1be-4eda-a382-999a5cc22b74","type":"BasicTickFormatter"},"plot":{"id":"71050f54-5b8d-445a-95f7-84babe487724","subtype":"Figure","type":"Plot"},"ticker":{"id":"78a3cf00-761e-48e9-8eac-9397ac09e711","type":"BasicTicker"}},"id":"f67468be-05e8-4e18-96c2-04ee67c719a8","type":"LinearAxis"},{"attributes":{"data_source":{"id":"6ce63332-1b4a-4525-9009-50fafe5e70f3","type":"ColumnDataSource"},"glyph":{"id":"c3c77278-5bcd-4ed8-980b-7545985afa5b","type":"Rect"},"hover_glyph":null,"nonselection_glyph":{"id":"dab7d273-76e1-4ef4-aeac-35edb33627d4","type":"Rect"},"selection_glyph":null},"id":"21dfe2a9-9c1e-483f-b94f-38c58f35b1c3","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[2.0,2.0],"y":[3.4,4.4]}},"id":"7c0612a7-8647-4fac-9fdc-98b349ec79e7","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"7c0612a7-8647-4fac-9fdc-98b349ec79e7","type":"ColumnDataSource"},"glyph":{"id":"059f3084-fa78-4a70-a88c-d62cafa28f1b","type":"Line"},"hover_glyph":null,"nonselection_glyph":{"id":"574f02af-bab5-418c-a0bc-92354b62fbb7","type":"Line"},"selection_glyph":null},"id":"97e27adc-50d9-49b0-a851-5ec5d4eef8b9","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"76add590-bd37-4dea-b846-bb0b5fec4d82","type":"Circle"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"574f02af-bab5-418c-a0bc-92354b62fbb7","type":"Line"},{"attributes":{"data_source":{"id":"20cdda83-41fb-4e0a-b9bb-5634d7ceac9c","type":"ColumnDataSource"},"glyph":{"id":"16ed2b58-5301-4507-b419-5fa6a2e8bb5f","type":"Rect"},"hover_glyph":null,"nonselection_glyph":{"id":"2307eaae-dc96-4a1f-894d-be5f6c643af1","type":"Rect"},"selection_glyph":null},"id":"8ab1bafb-945a-44b9-b740-f00956996e8e","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"ef80af32-ab42-4b9b-9a06-c0730e1044aa","type":"ColumnDataSource"},"glyph":{"id":"351bae91-e9f4-4292-8c61-2d0af8e5d717","type":"Rect"},"hover_glyph":null,"nonselection_glyph":{"id":"ed2e44a9-6b83-4344-9b7a-09ccfbe0b963","type":"Rect"},"selection_glyph":null},"id":"78beb7e8-ea09-4fae-a58c-926fdabb36f7","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"db70a814-9e36-443c-b8e5-0c574239694a","type":"ColumnDataSource"},"glyph":{"id":"ebf2e2f6-3b2d-4453-acea-6773f9222071","type":"Line"},"hover_glyph":null,"nonselection_glyph":{"id":"d498d021-26ae-439d-a669-4de5158ef913","type":"Line"},"selection_glyph":null},"id":"c62ae2ef-1d25-4f9f-b7e7-3279fa9ef699","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"ccf5a93d-a0b0-4766-8081-d8a1c9442de7","type":"ColumnDataSource"},"glyph":{"id":"00287e50-ad74-49c1-9a1b-7e99245e2ff7","type":"Line"},"hover_glyph":null,"nonselection_glyph":{"id":"27a2750a-9e70-4999-a1b3-4a2d2bf7e310","type":"Line"},"selection_glyph":null},"id":"7e36041c-7da2-4528-bb22-e419d423f85f","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[1.0,1.0],"y":[1.6,2.6]}},"id":"ccf5a93d-a0b0-4766-8081-d8a1c9442de7","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"e4f04f7e-1d14-4e22-9d46-790816aa108d","type":"ColumnDataSource"},"glyph":{"id":"61550caf-4fdc-4e46-bf3c-d98a6bd859c4","type":"Line"},"hover_glyph":null,"nonselection_glyph":{"id":"4e5aa995-70fc-4bd4-bb6e-e5bb5f70c031","type":"Line"},"selection_glyph":null},"id":"143d0ec2-952e-4808-aa28-185ea9e78b5f","type":"GlyphRenderer"},{"attributes":{"fill_color":{"value":"#e41a1c"},"height ...

# %% [markdown]
# ## Fitting
# QExPy easily handles fitting of data. A few common functions are automatically implemented (linear, polynomial, gaussian), but the used can also specify their own function. The fitting algorithm calls the scipy.optimize package in the background to perform the fit, and the fitted parameters are returned as Measurement objects (with uncertainties and correlations).
#
# A fit to a straight line of the above plot is easily done, and the residuals can also be shown. By default, the fit will show a  band around the fitted function computed using 1 standard error in the fitted parameters (and their correlation)

# %%
figure.fit("linear")
figure.add_residuals()
figure.show()
# Out:
# -----------------Fit results-------------------
# Fit of  dataset0  to  linear
# Fit parameters:
# dataset0_linear_fit0_fitpars_intercept = 0.0 +/- 0.4,
# dataset0_linear_fit0_fitpars_slope = 1.99 +/- 0.09
#
# Correlation matrix:
# [[ 1.    -0.894]
#  [-0.894  1.   ]]
#
# chi2/ndof = 0.07/4
# ---------------End fit results----------------
#     <div class="bk-root">
#         <div class="plotdiv" id="a1e8b19f-24c1-425f-8ce5-51f5d879eeb2"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("a1e8b19f-24c1-425f-8ce5-51f5d879eeb2");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'a1e8b19f-24c1-425f-8ce5-51f5d879eeb2' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"67b0f604-8dce-4073-9bcc-95c17441fd32":{"roots":{"references":[{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[6.0,6.0],"y":[-1.157142857153671,-0.15714285715367105]}},"id":"4cc54d4b-acfd-4ef7-92d2-16954d1c9828","type":"ColumnDataSource"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"045cc5e1-4d93-436c-ac32-7d6668e90e55","type":"Line"},{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":[3.0,3.0],"y":[-0.2000000000043647,0.7999999999956353]}},"id":"0ab701cc-5fd0-457a-b648-c1018bb7fbc3","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"value":0.3},"fill_color":{"value":"#e41a1c"},"line_alpha":{"value":0.0},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"7897d593-2150-433d-817e-5b08345f002e","type":"Patch"},{"attributes":{"data_source":{"id":"ca81b150-69f9-4055-b8be-d0594087e901","type":"ColumnDataSource"},"glyph":{"id":"3a05f01b-f345-4f40-89c8-d2ab27dd7477","type":"Circle"},"hover_glyph":null,"nonselection_glyph":{"id":"f6e009a8-a6aa-442b-91b0-d44449141679","type":"Circle"},"selection_glyph":null},"id":"1a4faaf5-21f6-484f-a5d6-7010f0d06696","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"1f9c46b3-f57b-43fb-938d-533fccdd8b48","type":"ColumnDataSource"},"glyph":{"id":"02d86dd9-968f-4055-b49c-07121b988009","type":"Line"},"hover_glyph":null,"nonselection_glyph":{"id":"7426d272-e002-4a7d-8ea7-0672290e3682","type":"Line"},"selection_glyph":null},"id":"4dc62da1-8f14-433b-9c6d-cda5242949a3","type":"GlyphRenderer"},{"attributes":{},"id":"8026f919-0dac-408f-bbb8-b58de599b692","type":"BasicTickFormatter"},{"attributes":{"data_source":{"id":"41dcc8a1-2c99-4674-b13f-a9549c8df7ec","type":"ColumnDataSource"},"glyph":{"id":"3e341f1a-30c6-47d1-8c93-7e48b24cf5a9","type":"Rect"},"hover_glyph":null,"nonselection_glyph":{"id":"2c7369fa-ccb9-4e71-8e76-a4debaba7fe6","type":"Rect"},"selection_glyph":null},"id":"a1e6639a-cbb8-45b7-8271-e67c0e6890a7","type":"GlyphRenderer"},{"attributes":{"callback":null,"end":17.55},"id":"6bdb5091-7375-495f-b768-a7b86d8a381e","type":"Range1d"},{"attributes":{"line_color":{"value":"#e41a1c"},"x":{"field":"x"},"y":{"field":"y"}},"id":"38cae388-43bf-4c6f-8d76-749089a2ac1a","type":"Line"},{"attributes":{"axis_label":"Residuals","formatter":{"id":"f096bd5c-fc25-4fea-95d7-e0bb2d2c487b","type":"BasicTickFormatter"},"plot":{"id":"b2f8a971-c088-45fe-bd83-990f03cd0fcd","subtype":"Figure","type":"Plot"},"ticker":{"id":"82a94955-190e-40be-87cb-c7fcb0b4cbee","type":"BasicTicker"}},"id":"04a4a3ec-5abb-4286-a318-815ea2b4b03c","type":"LinearAxis"},{"attributes":{"data_source":{"id":"48ed0ddf-5cf3-4edb-996a-2da51d9b3611","type":"ColumnDataSource"},"glyph":{"id":"3d020ffc-6b78-40b1-a448-24b874f87b1a","type":"Line"},"hover_glyph":null,"nonselection_glyph":{"id":"045cc5e1-4d93-436c-ac32-7d6668e90e55","type":"Line"},"selection_glyph":null},"id":"4b0f0406-847d-4094-a88b-64c48501861c","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[7.0,7.0],"y":[0.15714285712989273,1.1571428571298927]}},"id":"f9ee89d0-4fb2-49c2-bd08-5fa1a1b9b38d","type":"ColumnDataSource"},{"attributes":{"plot":{"id":"b2f8a971-c088-45fe-bd83-990f03cd0fcd","subtype":"Figure","type":"Plot"},"ticker":{"id":"72fa5912-905e-4ea8-8c28-3251a18a7c13","type":"BasicTicker"}},"id":"91546f3c-6ff9-40be-bad6-2eed504dfb41","type":"Grid"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[3.0,3.0],"y":[-0.2000000000043647,0.7999999999956353]}},"id":"1ec2562b-3652-4787-9946-890f8160659a","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"height":{"units":"screen","value":0.2},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"width":{"units":"screen","value":5},"x":{"field":"x"},"y":{"field":"y"}},"id":"5fc324db-070c-4abd-9f74-b410b91d7e4e","type":"Rect"},{"attributes":{"callback":null,"c ...

# %% [markdown]
# If the user wishes to specify a custom function to fit, then the function can be specified as a python function. The first argument to the function must be the dependent variable, and the second argument must be an array (or tuple) corresponding to the parameters to be fit.
#
# In order to properly fit the user-supplied function, QExPy needs to have a guess for the values of the parameters.

# %%
#Define a simple quadratic
def myModel(x, *parameters):
    return parameters[0]+parameters[1]*x+parameters[2]*x**2

#Carry out the fit
figure.fit(model=myModel, parguess=[1,1,2])
figure.show()
# Out:
# -----------------Fit results-------------------
# Fit of  dataset0  to  custom
# Fit parameters:
# dataset0_custom_fit1_fitpars_par0 = 0.5 +/- 0.8,
# dataset0_custom_fit1_fitpars_par1 = 1.7 +/- 0.4,
# dataset0_custom_fit1_fitpars_par2 = 0.04 +/- 0.05
#
# Correlation matrix:
# [[ 1.    -0.924  0.84 ]
#  [-0.924  1.    -0.977]
#  [ 0.84  -0.977  1.   ]]
#
# chi2/ndof = 0.83/3
# ---------------End fit results----------------
#     <div class="bk-root">
#         <div class="plotdiv" id="fdedabad-97b2-4018-80ec-9ca461dc2da1"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("fdedabad-97b2-4018-80ec-9ca461dc2da1");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'fdedabad-97b2-4018-80ec-9ca461dc2da1' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"d4ae89b6-dd06-4ba0-852d-873f7be8d928":{"roots":{"references":[{"attributes":{"data_source":{"id":"2518f01d-879d-4d3a-8a9b-70722f750005","type":"ColumnDataSource"},"glyph":{"id":"f4b7e785-cecf-4c06-a814-b517b2f5f7e3","type":"Circle"},"hover_glyph":null,"nonselection_glyph":{"id":"ad4e5d97-0aec-4d30-b690-117e2a36f1e9","type":"Circle"},"selection_glyph":null},"id":"0123ed8d-72b9-467e-9993-55d58643e2c6","type":"GlyphRenderer"},{"attributes":{"line_color":{"value":"#e41a1c"},"x":{"field":"x"},"y":{"field":"y"}},"id":"30014e5c-81ec-41d5-b285-ad2218a6578b","type":"Line"},{"attributes":{"data_source":{"id":"a92855f5-d6aa-434a-864e-b91f89a769fc","type":"ColumnDataSource"},"glyph":{"id":"3f633c05-75a5-47b1-a16d-60b73ce35090","type":"Line"},"hover_glyph":null,"nonselection_glyph":{"id":"e14efbec-178d-4130-9fe8-c9d015e12251","type":"Line"},"selection_glyph":null},"id":"80ad5836-2ec5-4e92-b09f-a98cd29483c4","type":"GlyphRenderer"},{"attributes":{"sizing_mode":"scale_width","toolbar_location":"above","tools":[{"id":"bfa4450e-bc71-4651-84a0-2431c0e284d8","type":"SaveTool"},{"id":"888d650d-a922-45ba-9a60-8d957cd0463f","type":"PanTool"},{"id":"8018afd6-3985-4b74-a06d-aebdc17f0e2a","type":"BoxZoomTool"},{"id":"f3666605-f5b3-4983-bcd5-b4014b0adfc2","type":"WheelZoomTool"},{"id":"7def33c8-dac3-473a-8517-cae9ea88ff2a","type":"ResetTool"},{"id":"73e59ebf-5635-4804-8f50-db33b355c0d2","type":"SaveTool"},{"id":"09daedbf-849f-481a-b5ac-9ff4be776c04","type":"PanTool"},{"id":"172c4c8b-7d30-4cc1-9026-d260a6b61538","type":"BoxZoomTool"},{"id":"62cdc4dd-b64a-46fc-b767-e903a1b978aa","type":"WheelZoomTool"},{"id":"f9a39829-6e5a-4301-b6d2-864343ba2e3d","type":"ResetTool"}]},"id":"cf3754a5-f321-4ea5-a6ac-257139a40550","type":"ToolbarBox"},{"attributes":{"below":[{"id":"04897ba0-b568-4438-be6e-57ab65299913","type":"LinearAxis"}],"left":[{"id":"5d61d265-6581-4f66-a02c-4f7e7c08b251","type":"LinearAxis"}],"plot_height":133,"renderers":[{"id":"04897ba0-b568-4438-be6e-57ab65299913","type":"LinearAxis"},{"id":"4a85f7f1-6141-49ba-9cf9-9ae849d39320","type":"Grid"},{"id":"5d61d265-6581-4f66-a02c-4f7e7c08b251","type":"LinearAxis"},{"id":"e91c29cb-de21-4e58-9eab-b829d50d6a5e","type":"Grid"},{"id":"50700758-d2db-4bc1-b1f3-03e4175a0f54","type":"BoxAnnotation"},{"id":"28300551-5bf8-4b17-bc93-9d3992975171","type":"GlyphRenderer"},{"id":"d848b0c4-8595-4c45-aa1e-f567c0663285","type":"GlyphRenderer"},{"id":"296d6fbf-ed97-48a0-8a9a-3bc8fcb28d6f","type":"GlyphRenderer"},{"id":"66263829-f720-4001-8448-76bb330a14ee","type":"GlyphRenderer"},{"id":"11f3e020-af08-4c3b-933e-22804ef94b93","type":"GlyphRenderer"},{"id":"3e96b155-5823-4d8a-9b56-7db5ff48ec1f","type":"GlyphRenderer"},{"id":"3397b7cf-ed34-4806-a0e6-f1bad96c3b9d","type":"GlyphRenderer"},{"id":"22b907e5-1ae9-4344-9cf4-242fa893d84f","type":"GlyphRenderer"},{"id":"b30e95d4-4a99-4018-8c8c-8b9eba3519eb","type":"GlyphRenderer"},{"id":"cb4f5f54-d573-4a02-b08b-6b092e933f3c","type":"GlyphRenderer"},{"id":"39cf6d24-99e1-43b5-872d-41287e906023","type":"GlyphRenderer"},{"id":"2b3d6ac8-5cf2-4b81-a3c0-86ec849e0645","type":"GlyphRenderer"},{"id":"1d43da80-1d52-499b-8a5d-54a338b260db","type":"GlyphRenderer"},{"id":"af838a4b-25ac-4219-a1df-d0c9c6fc241b","type":"GlyphRenderer"},{"id":"ee3ebec0-23bb-4fcf-ae51-4f169ffc8d68","type":"GlyphRenderer"}],"title":{"id":"125fd2a4-fd59-46e2-ba76-ff129b360120","type":"Title"},"tool_events":{"id":"a8ca1515-7a0e-4690-a503-076a84a096f8","type":"ToolEvents"},"toolbar":{"id":"032ff704-156d-4393-b000-efaff79a0565","type":"Toolbar"},"toolbar_location":null,"x_range":{"id":"59845e52-b1f7-468e-88d0-5d399429a188","type":"Range1d"},"y_range":{"id":"c719d9e9-8b62-4d56-b374-d99d5858cabe","type":"Range1d"}},"id":"b6a7e878-e1e4-4638-8902-7baaec54f02f","subtype":"Figure","type":"Plot"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"height":{"units":"screen","value":0.2},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"width":{"units":"screen","value":5} ...

# %% [markdown]
# ## Showing multiple data sets on one figure
# QExPy can also show multiple data sets on the same plot, and each data set can have its own individual fit.
#
# Suppose that we have a second set of measurement of the y values for the same x values as above. The easiest way to plot them along with the initial values, is to create a DataSet and to add that Dataset to the figure:

# %%
y2 = q.MeasurementArray([2.4,4.2,5.9,8.2,9.2,12.0,13.6], error=[0.5], name="force", units="N")
dataset = q.XYDataSet(x,y2)
figure.add_dataset(dataset)
figure.show()
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="2f5310d8-6c0f-4ce9-a213-71b9e712a52d"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("2f5310d8-6c0f-4ce9-a213-71b9e712a52d");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '2f5310d8-6c0f-4ce9-a213-71b9e712a52d' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"6193d251-58e7-4a49-9f01-74cdf1edd307":{"roots":{"references":[{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[3.0,3.0],"y":[-0.07857142853624932,0.9214285714637507]}},"id":"5b596139-4908-4d12-90d6-69539bd57c90","type":"ColumnDataSource"},{"attributes":{"callback":null,"end":7.5},"id":"d6424b6a-4008-40e0-b2d2-cb6444e0225d","type":"Range1d"},{"attributes":{"fill_color":{"value":"#e41a1c"},"height":{"units":"screen","value":0.2},"line_color":{"value":"#e41a1c"},"width":{"units":"screen","value":5},"x":{"field":"x"},"y":{"field":"y"}},"id":"98c7d851-1e0d-4e53-8334-1d10c2312e97","type":"Rect"},{"attributes":{"fill_color":{"value":"#e41a1c"},"height":{"units":"screen","value":0.2},"line_color":{"value":"#e41a1c"},"width":{"units":"screen","value":5},"x":{"field":"x"},"y":{"field":"y"}},"id":"3ef59688-5fec-4405-844c-7d533c7a73d6","type":"Rect"},{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":[4.0,4.0],"y":[7.699999999999999,8.7]}},"id":"e4dd1fb1-d66a-46cd-91dd-9db776d32be3","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"height":{"units":"screen","value":0.2},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"width":{"units":"screen","value":5},"x":{"field":"x"},"y":{"field":"y"}},"id":"b7b4dbb5-d637-4257-9292-377f59e4e771","type":"Rect"},{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":[4.0,4.0],"y":[7.6,8.6]}},"id":"262cc7f2-f659-428c-a0cd-fb01b5058fd1","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"height":{"units":"screen","value":0.2},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"width":{"units":"screen","value":5},"x":{"field":"x"},"y":{"field":"y"}},"id":"f2cde7da-776f-410b-b95d-c6f7909d5217","type":"Rect"},{"attributes":{"data_source":{"id":"f8d5b4b7-60ef-4486-8621-dae9d139b090","type":"ColumnDataSource"},"glyph":{"id":"b75f280e-8ea5-40cc-8d57-6283c9fec212","type":"Line"},"hover_glyph":null,"nonselection_glyph":{"id":"f6d040ee-b5a8-47d3-a9d1-226715507596","type":"Line"},"selection_glyph":null},"id":"9aca562d-3761-4a14-8ed7-4bb3b9ba29ac","type":"GlyphRenderer"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"22b3e91a-ee3d-4d0d-af43-a5b30bd01763","type":"Line"},{"attributes":{},"id":"8966f9c7-a4e8-4dd8-bfe4-34494a62e55a","type":"ToolEvents"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"f85a4530-30b7-42fa-b3db-b5fc6b14e7d8","type":"Line"},{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":[2.0,2.0],"y":[3.7,4.7]}},"id":"25937de3-1d2f-4b04-985c-f3d2d19b7ce5","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[5.0,5.0],"y":[9.1,10.1]}},"id":"268e9421-2efd-46a7-b6db-3cfa09865f0f","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"height":{"units":"screen","value":0.2},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"width":{"units":"screen","value":5},"x":{"field":"x"},"y":{"field":"y"}},"id":"3886ca5b-f07e-4588-8bd5-730a92460569","type":"Rect"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[4.0,4.0],"y":[-0.22380952374587437,0.7761904762541256]}},"id":"454233d0-1f0a-4edd-a356-b468da1be5d7","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":[3.0,3.0],"y":[-0.07857142853624932,0.9214285714637507]}},"id":"b8664b4e-b49f-494e-9708-6ce22c82bfa9","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"d82e969f-50ea-46c1-a258-ad56d7d01cca","type":"Circle"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field": ...
