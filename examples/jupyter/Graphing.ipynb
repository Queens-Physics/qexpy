# %% [markdown]
# # Plotting with QExPy
# The first step is to import the module, we import it as p.
# We will also import the error module so that we can plot Measurement objects

# %%
import qexpy as q
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="0bc24664-11a1-479a-9d4c-9dce73552c50">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# The most common scenario in undergraduate laboratories is that we have measured some "depedent" quantity, $y$, as we varied some "independent" quantity $x$. Let us suppose that we have such a set of measurements, where the $x$ values had negligible (zero) uncertainty, and the y values each have the same uncertainty.
#
# We can represent the data using the MeasurementArray object:

# %%
x = q.MeasurementArray([1,2,3,4,5,6,7], error=[0], name="length", units="m")
y = q.MeasurementArray([2.1,3.9,6.3,8.1,9.6,11.3,14.6], error=[0.5], name="force", units="N")

# %% [markdown]
# We can now make a plot of $y$ versus $x$ and "show" it:

# %%
figure = q.MakePlot(x,y)
figure.show()
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="19fc4ac0-4ada-430f-a9c4-c18d57e08699"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("19fc4ac0-4ada-430f-a9c4-c18d57e08699");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '19fc4ac0-4ada-430f-a9c4-c18d57e08699' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"d42a6458-0df4-417e-b138-58c239ee1664":{"roots":{"references":[{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"ada922e1-b743-4030-8144-27ea8d4b26e4","type":"Line"},{"attributes":{"data_source":{"id":"f8d8d177-7640-4bd5-85f5-444be8e560a2","type":"ColumnDataSource"},"glyph":{"id":"6c04227a-b3bb-4f2c-ab2f-f6fbc29a3255","type":"Rect"},"hover_glyph":null,"nonselection_glyph":{"id":"e7bc6271-1290-4d26-a973-e5e1ed866bfd","type":"Rect"},"selection_glyph":null},"id":"6badec08-a43e-478b-bc82-e5258ee9e7e4","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"height":{"units":"screen","value":0.2},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"width":{"units":"screen","value":5},"x":{"field":"x"},"y":{"field":"y"}},"id":"d12796f5-e171-481b-93be-433f8e551580","type":"Rect"},{"attributes":{},"id":"3ff034a8-70a2-453a-9059-0a5b5626026b","type":"BasicTicker"},{"attributes":{"axis_label":"force [N]","formatter":{"id":"78c0aa0f-063f-4a4b-bdcc-1135224bc55f","type":"BasicTickFormatter"},"plot":{"id":"73a23752-6461-4cfb-bb82-6e72dfddaaab","subtype":"Figure","type":"Plot"},"ticker":{"id":"d0750f21-16f7-4c5e-b722-c93412e8049c","type":"BasicTicker"}},"id":"affc16bf-5b89-4701-89be-bb6a9cb9ddaa","type":"LinearAxis"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[1.0,1.0],"y":[1.6,2.6]}},"id":"17c4650c-0aae-4d30-b514-6440ac4bdc73","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"7fd01769-cc99-435d-953e-a9bc29ab9b77","type":"ColumnDataSource"},"glyph":{"id":"eb3c4385-ac82-4b6b-8d21-46c7939f402d","type":"Line"},"hover_glyph":null,"nonselection_glyph":{"id":"ada922e1-b743-4030-8144-27ea8d4b26e4","type":"Line"},"selection_glyph":null},"id":"d95dd5a0-14a6-4e62-a4e3-222c83e52174","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":[7.0,7.0],"y":[14.1,15.1]}},"id":"d079aa76-cb8b-4365-870a-783df24c0ba4","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"17c4650c-0aae-4d30-b514-6440ac4bdc73","type":"ColumnDataSource"},"glyph":{"id":"44367d17-b206-4fc9-93b0-6287d0132bfa","type":"Line"},"hover_glyph":null,"nonselection_glyph":{"id":"e60c1137-d0f4-4a36-a6d6-b7d0cb3eb7f0","type":"Line"},"selection_glyph":null},"id":"1d0dfde9-12a4-4157-8b9d-9709b40fbc98","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[5.0,5.0],"y":[9.1,10.1]}},"id":"7601d5a7-c883-42e3-af58-5f446faee0ce","type":"ColumnDataSource"},{"attributes":{"line_color":{"value":"#e41a1c"},"x":{"field":"x"},"y":{"field":"y"}},"id":"1cb940a2-8583-40fb-89d4-b8cdcb829b6b","type":"Line"},{"attributes":{"fill_color":{"value":"#e41a1c"},"height":{"units":"screen","value":0.2},"line_color":{"value":"#e41a1c"},"width":{"units":"screen","value":5},"x":{"field":"x"},"y":{"field":"y"}},"id":"ca46ea19-8392-4205-b32e-aca5ce8fcbbf","type":"Rect"},{"attributes":{},"id":"2ee43f51-673b-43b4-af42-4daabae79435","type":"BasicTickFormatter"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"height":{"units":"screen","value":0.2},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"width":{"units":"screen","value":5},"x":{"field":"x"},"y":{"field":"y"}},"id":"5dc61f9b-e55e-42be-8c23-845e1e3f984c","type":"Rect"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[4.0,4.0],"y":[7.6,8.6]}},"id":"58489a02-0b6c-4e40-b289-85314d3fe683","type":"ColumnDataSource"},{"attributes":{"line_color":{"value":"#e41a1c"},"x":{"field":"x"},"y":{"field":"y"}},"id":"44367d17-b206-4fc9-93b0-6287d0132bfa","type":"Line"},{"attributes":{"legends":[["dataset0",[{"id":"a35f14d3-297d-4842-b6ff-20cae779fc64","type":"GlyphRenderer"}]]],"location":"top_left","plot":{"id":"73a23752-6461-4cfb-bb82-6e72dfddaaab","subtype":"Figure","type":"Plot"}},"id":"e3e9b746-5fcf-4c74-aa39-918ef5b9afaf","type":"Legend"},{"attributes":{"below":[{ ...

# %% [markdown]
# ## Fitting
# QExPy easily handles fitting of data. A few common functions are automatically implemented (linear, polynomial, gaussian), but the used can also specify their own function. The fitting algorithm calls the scipy.optimize package in the background to perform the fit, and the fitted parameters are returned as Measurement objects (with uncertainties and correlations).
#
# A fit to a straight line of the above plot is easily done, and the residuals can also be shown. By default, the fit will show a  band around the fitted function computed using 1 standard error in the fitted parameters (and their correlation)

# %%
figure.fit("linear")
figure.add_residuals()
figure.show()
# Out:
# -----------------Fit results-------------------
# Fit of  dataset0  to  linear
# Fit parameters:
# dataset0_linear_fit0_fitpars_intercept = 0.0 +/- 0.4,
# dataset0_linear_fit0_fitpars_slope = 1.99 +/- 0.09
#
# Correlation matrix:
# [[ 1.    -0.894]
#  [-0.894  1.   ]]
#
# chi2/ndof = 0.07/4
# ---------------End fit results----------------
#     <div class="bk-root">
#         <div class="plotdiv" id="87f82451-8dd4-4daa-9b57-3860e833622f"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("87f82451-8dd4-4daa-9b57-3860e833622f");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '87f82451-8dd4-4daa-9b57-3860e833622f' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"2da413ff-0108-461c-818d-3b847044b476":{"roots":{"references":[{"attributes":{},"id":"d044ea5a-ac58-402b-b9e3-c798ec2e7995","type":"BasicTicker"},{"attributes":{"dimension":1,"plot":{"id":"74b1300d-128d-49b2-8951-d1db24b28033","subtype":"Figure","type":"Plot"},"ticker":{"id":"be439e4a-9a5b-46ec-afc6-96830cc7058c","type":"BasicTicker"}},"id":"4d6e4239-dfe8-47ec-ac76-5636f38e8050","type":"Grid"},{"attributes":{"data_source":{"id":"54fc29ee-84ab-4867-8922-f6bc2df6f621","type":"ColumnDataSource"},"glyph":{"id":"871c8561-137a-407e-bd60-ec6c15b188bb","type":"Rect"},"hover_glyph":null,"nonselection_glyph":{"id":"f94445d1-3fae-4c35-b49b-4e80167bed60","type":"Rect"},"selection_glyph":null},"id":"987b66df-2b25-41a2-a6cd-a487f82d248a","type":"GlyphRenderer"},{"attributes":{"line_color":{"value":"#e41a1c"},"x":{"field":"x"},"y":{"field":"y"}},"id":"18d70322-2017-4480-b1b6-c1a898751397","type":"Line"},{"attributes":{"data_source":{"id":"2d4747f6-cfc6-45c8-a8f9-6a5015f50999","type":"ColumnDataSource"},"glyph":{"id":"1c52ad2a-440e-4ebe-98f2-013cfdc1899b","type":"Line"},"hover_glyph":null,"nonselection_glyph":{"id":"98848975-73f6-474d-8b63-834227e6ae44","type":"Line"},"selection_glyph":null},"id":"62f8d52e-c589-4f45-a33d-391ce7cd40ad","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[7.0,7.0],"y":[0.15714285712989273,1.1571428571298927]}},"id":"6fdb8573-0df0-42e6-bd9e-1264d44e9d80","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[1.0,1.1224489795918366,1.2448979591836735,1.3673469387755102,1.489795918367347,1.6122448979591837,1.7346938775510203,1.8571428571428572,1.9795918367346939,2.1020408163265305,2.2244897959183674,2.3469387755102042,2.4693877551020407,2.5918367346938775,2.7142857142857144,2.836734693877551,2.9591836734693877,3.0816326530612246,3.204081632653061,3.326530612244898,3.4489795918367347,3.571428571428571,3.693877551020408,3.816326530612245,3.9387755102040813,4.061224489795919,4.183673469387755,4.3061224489795915,4.428571428571429,4.551020408163265,4.673469387755102,4.795918367346939,4.918367346938775,5.040816326530612,5.163265306122449,5.285714285714286,5.408163265306122,5.530612244897959,5.653061224489796,5.775510204081632,5.8979591836734695,6.020408163265306,6.142857142857142,6.26530612244898,6.387755102040816,6.5102040816326525,6.63265306122449,6.755102040816326,6.877551020408163,7.0],"y":[2.028571428571493,2.271720116618403,2.514868804665314,2.758017492712224,3.0011661807591348,3.2443148688060455,3.4874635568529557,3.7306122448998664,3.9737609329467767,4.216909620993687,4.460058309040598,4.703206997087508,4.946355685134418,5.189504373181329,5.4326530612282395,5.675801749275149,5.91895043732206,6.162099125368972,6.4052478134158815,6.648396501462792,6.891545189509703,7.134693877556613,7.377842565603523,7.620991253650434,7.864139941697344,8.107288629744255,8.350437317791165,8.593586005838075,8.836734693884987,9.079883381931896,9.323032069978806,9.566180758025718,9.809329446072628,10.052478134119538,10.295626822166449,10.538775510213359,10.781924198260269,11.02507288630718,11.26822157435409,11.511370262401,11.754518950447912,11.997667638494823,12.240816326541733,12.483965014588644,12.727113702635554,12.970262390682464,13.213411078729376,13.456559766776286,13.699708454823195,13.942857142870107]}},"id":"81f00fa5-23ea-474f-a8f6-e14ce37a8af7","type":"ColumnDataSource"},{"attributes":{"line_color":{"value":"#e41a1c"},"x":{"field":"x"},"y":{"field":"y"}},"id":"fe8a45b5-9518-46a2-855c-c37c32a9486b","type":"Line"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[3.0,3.0],"y":[5.8,6.8]}},"id":"631ecac8-ca21-47ee-a4b0-177b10694653","type":"ColumnDataSource"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"c13e55f0-022f-47c0-bcd4-a736017b7f33","type":"Line"},{"attributes":{"line_color":{"value":"#e41a1c"},"x":{"field":"x"},"y":{"fie ...

# %% [markdown]
# If the user wishes to specify a custom function to fit, then the function can be specified as a python function. The first argument to the function must be the dependent variable, and the second argument must be an array (or tuple) corresponding to the parameters to be fit.
#
# In order to properly fit the user-supplied function, QExPy needs to have a guess for the values of the parameters.

# %%
#Define a simple quadratic
def myModel(x, *parameters):
    return parameters[0]+parameters[1]*x+parameters[2]*x**2

#Carry out the fit
figure.fit(model=myModel, parguess=[1,1,2])
figure.show()
# Out:
# -----------------Fit results-------------------
# Fit of  dataset0  to  custom
# Fit parameters:
# dataset0_custom_fit1_fitpars_par_0 = 0.5 +/- 0.8,
# dataset0_custom_fit1_fitpars_par_1 = 1.7 +/- 0.4,
# dataset0_custom_fit1_fitpars_par_2 = 0.04 +/- 0.05
#
# Correlation matrix:
# [[ 1.    -0.924  0.84 ]
#  [-0.924  1.    -0.977]
#  [ 0.84  -0.977  1.   ]]
#
# chi2/ndof = 0.83/3
# ---------------End fit results----------------
#     <div class="bk-root">
#         <div class="plotdiv" id="4d2f51d0-9735-4a5e-a2c5-04bdba31ec64"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("4d2f51d0-9735-4a5e-a2c5-04bdba31ec64");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '4d2f51d0-9735-4a5e-a2c5-04bdba31ec64' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"1d255f26-87d3-4d7c-8a26-66566036fc2c":{"roots":{"references":[{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"9683555f-37de-4989-9076-2a6c9be86e29","type":"Line"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"10f323e8-afb5-4fb3-860e-6847b77340ea","type":"Line"},{"attributes":{"data_source":{"id":"e84c16cf-768e-46d7-89c1-b8739c288ac6","type":"ColumnDataSource"},"glyph":{"id":"064205cb-0de2-4da3-8024-f340b595320b","type":"Line"},"hover_glyph":null,"nonselection_glyph":{"id":"f0b1794c-7c14-406b-a09d-41c8a01ff232","type":"Line"},"selection_glyph":null},"id":"65fb543e-fcae-44e4-8c28-8698793d90a0","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":[5.0,5.0],"y":[-0.7499999998993232,0.2500000001006768]}},"id":"e48ada89-d69e-48e3-a859-1fef1236bc48","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"61085380-e742-4cd3-beb1-de82c501c47b","type":"ColumnDataSource"},"glyph":{"id":"a4c153b7-1dd9-45ee-a975-d8f1ae208b8a","type":"Rect"},"hover_glyph":null,"nonselection_glyph":{"id":"a795fd3f-edf7-4d9c-966f-17c3b0c31623","type":"Rect"},"selection_glyph":null},"id":"22cb958d-0f24-479a-b910-4f9722e79f3c","type":"GlyphRenderer"},{"attributes":{"fill_color":{"value":"#e41a1c"},"height":{"units":"screen","value":0.2},"line_color":{"value":"#e41a1c"},"width":{"units":"screen","value":5},"x":{"field":"x"},"y":{"field":"y"}},"id":"e9e1a3b5-ce1d-47d8-8e64-247c21e02592","type":"Rect"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[7.0,7.0],"y":[14.1,15.1]}},"id":"ece62545-f554-4476-9f9e-d6a116420e7c","type":"ColumnDataSource"},{"attributes":{"overlay":{"id":"b37617f0-04b1-4af9-944c-9d6f91f736cd","type":"BoxAnnotation"},"plot":{"id":"13cc1f84-f5b8-4407-83c7-aaff128aad31","subtype":"Figure","type":"Plot"}},"id":"55477d1e-e216-4b0a-88b7-1c50a11a0a1b","type":"BoxZoomTool"},{"attributes":{"data_source":{"id":"1bbb5e0a-ac0e-4eed-ae47-12213d053db9","type":"ColumnDataSource"},"glyph":{"id":"d405c7e2-8d4f-46e1-9f18-839e821fd531","type":"Rect"},"hover_glyph":null,"nonselection_glyph":{"id":"b3319c5d-6f82-42b9-ad0c-b97a1bf1f9a9","type":"Rect"},"selection_glyph":null},"id":"2222fe56-a83b-400d-a147-39704e67040c","type":"GlyphRenderer"},{"attributes":{"line_color":{"value":"#e41a1c"},"x":{"field":"x"},"y":{"field":"y"}},"id":"a2ecd130-4d5c-4f38-8648-dd370db6aa6b","type":"Line"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"233b291f-4a73-43ea-ae45-c37929130216","type":"Line"},{"attributes":{"line_color":{"value":"#e41a1c"},"x":{"field":"x"},"y":{"field":"y"}},"id":"178a468f-6232-43e9-a87e-2889e8b5c925","type":"Line"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"45d63593-a5bb-4743-bd1c-ad9ad295d255","type":"BoxAnnotation"},{"attributes":{"dimension":1,"plot":{"id":"0611b6cf-48c2-4c4b-a75d-e2c6beb5fe9c","subtype":"Figure","type":"Plot"},"ticker":{"id":"62d4a63d-0fc3-4374-9687-f8ae21d869f3","type":"BasicTicker"}},"id":"7e2cb5c5-777c-4361-b469-9bca6de2d47a","type":"Grid"},{"attributes":{"data_source":{"id":"7259fe86-49a5-477f-afa0-77e1356ef462","type":"ColumnDataSource"},"glyph":{"id":"aa9add73-34b6-40d1-9a6c-042b6e0f6fbf","type":"Rect"},"hover_glyph":null,"nonselection_glyph":{"id":"445375c1-1ab1-44c5-b7b1-bece540e84df","type":"Rect"},"selection_glyph":null},"id":"97be2bfd-fd5e-4637-b037-c76e177bea14","type":"GlyphRenderer"},{"attributes":{"fill_color":{"value":"#e41a1c"},"height":{"units":"screen","value":0.2},"line_color":{"value":"#e41a1c"},"width":{"units":"screen","value":5},"x" ...

# %% [markdown]
# ## Showing multiple data sets on one figure
# QExPy can also show multiple data sets on the same plot, and each data set can have its own individual fit.
#
# Suppose that we have a second set of measurement of the y values for the same x values as above. The easiest way to plot them along with the initial values, is to create a DataSet and to add that Dataset to the figure:

# %%
y2 = q.MeasurementArray([2.4,4.2,5.9,8.2,9.2,12.0,13.6], error=[0.5], name="force", units="N")
dataset = q.XYDataSet(x,y2)
figure.add_dataset(dataset)
figure.show()
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="f5ca5f52-b01f-48cc-a3d5-d4e132f1b7eb"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("f5ca5f52-b01f-48cc-a3d5-d4e132f1b7eb");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'f5ca5f52-b01f-48cc-a3d5-d4e132f1b7eb' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"